# %%
import tweepy
from kafka import KafkaProducer
from json import dumps
import time
import json

# %%
#Authenticate on Twitter

consumer_key = "dmn51aowr3bYzIWz3ELgARN5x"
consumer_secret = "Q6vHf7FNj1yDvX2vggN6kKLgiDP7t7HL5DNpNvK0akyjzfxTFt"
access_token = "164266780-hcTZEl441WUst50TpiRIZtAd3IHmvPDX5tQUDjqx"
access_token_secret = "AIoEwy9AL52AuHRAKesBph3arofQ4AdLwqYRl8tFnehxd"
auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_token, access_token_secret)

api = tweepy.API(auth)

# %%
#Create Kafka Producer

ip = 'localhost' #"35.228.250.247"
producer = KafkaProducer(bootstrap_servers=[ip+':9092'],
                         value_serializer=lambda x: 
                         dumps(x).encode('utf-8'))

# %%
#Retrieve TopN Hashtags on the given location

location = 2487956 #san francisco
n = 3 #top n parameter
top_n = [x.get("name") for x in api.trends_place(location)[0].get('trends')[0:n]]
print(top_n)
# Out:
# ['#UFCBoston', 'Chase Center', 'Tulsi']

# %%
#Define Listener

class ParallelListener(tweepy.StreamListener):
    def __init__(self,time_limit=60):
        self.start_time = time.time()
        self.limit = time_limit
        super(ParallelListener, self).__init__()

    def on_status(self, status):
        if (time.time() - self.start_time) < self.limit:
            data = {}
            data['date'] = str(status.created_at)
            data['tweet'] = status.text
            json_data = json.dumps(data)
            producer.send("test",json_data)
            print(json_data)
            return True
        else:
            print("Stopping stream..")
            return False

#Launch all listener together

listener = ParallelListener(time_limit=1000)
myStream = tweepy.Stream(auth = api.auth, listener=listener)
myStream.filter(track=top_n, is_async=False, languages=["en"])
# Out:
# {"date": "2019-10-19 08:42:34", "tweet": "RT @comeatmeehoe: #YangGang Van Jones is now trending for defending Tulsi. We need to offer him our support. https://t.co/DgDRO7LCbB"}
# {"date": "2019-10-19 08:42:34", "tweet": "RT @Gwynnion: Tulsi Gabbard, noted Assad apologist and 2020 third party voter bait, endorsed by Steve Bannon and David Duke and a regular o\u2026"}
# {"date": "2019-10-19 08:42:34", "tweet": "RT @JackPosobiec: Hillary picked a fight with Tulsi the same day the State Dept report on her illegal server came out"}
# {"date": "2019-10-19 08:42:34", "tweet": "RT @btsportufc: One more? \ud83d\ude4f\n\nDC wants that trilogy with Miocic.\n\n#UFCBoston https://t.co/aJkJVHsYKU"}
# {"date": "2019-10-19 08:42:35", "tweet": "RT @davidmweissman: I\u2019m pulling my hair out explaining to Tulsi supporters why it\u2019s bad going on Fox News, and they just don\u2019t get it and n\u2026"}
# {"date": "2019-10-19 08:42:35", "tweet": "RT @realTuckFrumper: Tulsi Fires Back And Proves Hillary Clinton's Tweet Correct https://t.co/ynVnQxwTiC"}
# {"date": "2019-10-19 08:42:35", "tweet": "RT @NotCarKing: @RAZ0RFIST With this latest accusation at Tulsi from Hillary and the media marching in goose step to back Hillary, the mask\u2026"}
# {"date": "2019-10-19 08:42:35", "tweet": "RT @EmeraldRobinson: Hillary Clinton and her gang are taking potshots at Tulsi Gabbard today because they want to obscure the news of their\u2026"}
# {"date": "2019-10-19 08:42:35", "tweet": "RT @yangp84: To all those #YangGang who jumped ship cause Andrew supported tulsi, you guys we're never true supporters. Andrew stood up for\u2026"}
# {"date": "2019-10-19 08:42:35", "tweet": "RT @TulsiGabbard: DNC/corporate media claims: \u2018we\u2019re not rigging anything.\u2019 Really? \n\u2014Vrindavan (Tulsi\u2019s sister)\n\nSpeaking time allotted at\u2026"}
# ---------------------------------------------------------------------------
# WantReadError                             Traceback (most recent call last)
# ~/anaconda3/lib/python3.7/site-packages/urllib3/contrib/pyopenssl.py in recv_into(self, *args, **kwargs)
#     296         try:
# --> 297             return self.connection.recv_into(*args, **kwargs)
#     298         except OpenSSL.SSL.SysCallError as e:
#
# ~/anaconda3/lib/python3.7/site-packages/OpenSSL/SSL.py in recv_into(self, buffer, nbytes, flags)
#    1821             result = _lib.SSL_read(self._ssl, buf, nbytes)
# -> 1822         self._raise_ssl_error(self._ssl, result)
#    1823
#
# ~/anaconda3/lib/python3.7/site-packages/OpenSSL/SSL.py in _raise_ssl_error(self, ssl, result)
#    1621         if error == _lib.SSL_ERROR_WANT_READ:
# -> 1622             raise WantReadError()
#    1623         elif error == _lib.SSL_ERROR_WANT_WRITE:
#
# WantReadError:
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-6-fc182f2558d5> in <module>
#      24 listener = ParallelListener(time_limit=1000)
#      25 myStream = tweepy.Stream(auth = api.auth, listener=listener)
# ---> 26 myStream.filter(track=top_n, is_async=False, languages=["en"])
#
# ~/anaconda3/lib/python3.7/site-packages/tweepy/streaming.py in filter(self, follow, track, is_async, locations, stall_warnings, languages, encoding, filter_level)
#     472             self.body['filter_level'] = filter_level.encode(encoding)
#     473         self.session.params = {'delimited': 'length'}
# --> 474         self._start(is_async)
#     475
#     476     def sitestream(self, follow, stall_warnings=False,
#
# ~/anaconda3/lib/python3.7/site-packages/tweepy/streaming.py in _start(self, is_async)
#     387             self._thread.start()
#     388         else:
# --> 389             self._run()
#     390
#     391     def on_closed(self, resp):
#
# ~/anaconda3/lib/python3.7/site-packages/tweepy/streaming.py in _run(self)
#     287                     self.snooze_time = self.snooze_time_step
#     288                     self.listener.on_connect()
# --> 289                     self._read_loop(resp)
#     290             except (Timeout, ssl.SSLError) as exc:
#     291                 # This is still necessary, as a SSLError can actually be
#
# ~/anaconda3/lib/python3.7/site-packages/tweepy/streaming.py in _read_loop(self, resp)
#     337             length = 0
#     338             while not resp.raw.closed:
# --> 339                 line = buf.read_line()
#     340                 stripped_line = line.strip() if line else line # line is sometimes None so we need to check here
#     341                 if not stripped_line:
#
# ~/anaconda3/lib/python3.7/site-packages/tweepy/streaming.py in read_line(self, sep)
#     198             else:
#     199                 start = len(self._buffer)
# --> 200             self._buffer += self._stream.read(self._chunk_size)
#     201         return six.b('')
#     202
#
# ~/anaconda3/lib/python3.7/site-packages/urllib3/response.py in read(self, amt, decode_content, cache_content)
#     440             else:
#     441                 cache_content = False
# --> 442                 data = self._fp.read(amt)
#     443                 if amt != 0 and not data:  # Platform-specific: Buggy versions of Python.
#     444                     # Close the connection when no data is returned
#
# ~/anaconda3/lib/python3.7/http/client.py in read(self, amt)
#     445             # Amount is given, implement using readinto
#     446             b = bytearray(amt)
# --> 447             n = self.readinto(b)
#     448             return memoryview(b)[:n].tobytes()
#     449         else:
#
# ~/anaconda3/lib/python3.7/http/client.py in readinto(self, b)
#     479
#     480         if self.chunked:
# --> 481             return self._readinto_chunked(b)
#     482
#     483         if self.length is not None:
#
# ~/anaconda3/lib/python3.7/http/client.py in _readinto_chunked(self, b)
#     574         try:
#     575             while True:
# --> 576                 chunk_left = self._get_chunk_left()
#     577                 if chunk_left is None:
#     578                     return total_bytes
#
# ~/anaconda3/lib/python3.7/http/client.py in _get_chunk_left(self)
#     542                 self._safe_read(2)  # toss the CRLF at the end of the chunk
#     543             try:
# --> 544                 chunk_left = self._read_next_chunk_size()
#     545             except ValueError:
#     546                 raise IncompleteRead(b'')
#
# ~/anaconda3/lib/python3.7/http/client.py in _read_next_chunk_size(self)
#     502     def _read_next_chunk_size(self):
#     503         # Read the next chunk size from the file
# --> 504         line = self.fp.readline(_MAXLINE + 1)
#     505         if len(line) > _MAXLINE:
#     506             raise LineTooLong("chunk size")
#
# ~/anaconda3/lib/python3.7/socket.py in readinto(self, b)
#     587         while True:
#     588             try:
# --> 589                 return self._sock.recv_into(b)
#     590             except timeout:
#     591                 self._timeout_occurred = True
#
# ~/anaconda3/lib/python3.7/site-packages/urllib3/contrib/pyopenssl.py in recv_into(self, *args, **kwargs)
#     307                 raise
#     308         except OpenSSL.SSL.WantReadError:
# --> 309             if not util.wait_for_read(self.socket, self.socket.gettimeout()):
#     310                 raise timeout('The read operation timed out')
#     311             else:
#
# ~/anaconda3/lib/python3.7/site-packages/urllib3/util/wait.py in wait_for_read(sock, timeout)
#     141     Returns True if the socket is readable, or False if the timeout expired.
#     142     """
# --> 143     return wait_for_socket(sock, read=True, timeout=timeout)
#     144
#     145
#
# ~/anaconda3/lib/python3.7/site-packages/urllib3/util/wait.py in poll_wait_for_socket(sock, read, write, timeout)
#     102         return poll_obj.poll(t)
#     103
# --> 104     return bool(_retry_on_intr(do_poll, timeout))
#     105
#     106
#
# ~/anaconda3/lib/python3.7/site-packages/urllib3/util/wait.py in _retry_on_intr(fn, timeout)
#      40     # Modern Python, that retries syscalls by default
#      41     def _retry_on_intr(fn, timeout):
# ---> 42         return fn(timeout)
#      43 else:
#      44     # Old and broken Pythons.
#
# ~/anaconda3/lib/python3.7/site-packages/urllib3/util/wait.py in do_poll(t)
#     100         if t is not None:
#     101             t *= 1000
# --> 102         return poll_obj.poll(t)
#     103
#     104     return bool(_retry_on_intr(do_poll, timeout))
#
# KeyboardInterrupt:

# %%
#Define Listener

class PipelineListener(tweepy.StreamListener):
    def __init__(self,tag,time_limit=60):
        self.start_time = time.time()
        self.limit = time_limit
        self.tag=tag
        super(PipelineListener, self).__init__()

    def on_status(self, status):
        if (time.time() - self.start_time) < self.limit:
            data = {}
            data['tag'] = self.tag
            data['date'] = str(status.created_at).split(" ")[0]#Keep the date, remove time
            data['tweet'] = status.text
            producer.send("DIC",data)
            print(data)
            return True
        else:
            print("Stopping stream..")
            return False

#Launch listener in series

time_limit = 1000

for _ in range(0,5):
    listeners = []
    streams = []
    for i in range(0,n):
        print(top_n[i])
        listeners.append(PipelineListener(top_n[i],time_limit=time_limit))
        streams.append(tweepy.Stream(auth = api.auth, listener=listeners[i]))
        streams[i].filter(track=[top_n[i]], is_async=False, languages=["en"])
        streams[i].disconnect()
# Out:
# #UFCBoston
# {'tag': '#UFCBoston', 'date': '2019-10-19', 'tweet': 'RT @MMAFighting: @JoeLauzon Lauzon gets the TKO at 1:33 of the first round at home  🍀\n#UFCBoston photos by Thomas Lakes https://t.co/GsAzrO…'}
# {'tag': '#UFCBoston', 'date': '2019-10-19', 'tweet': 'RT @btsportufc: Dominick Reyes is a problem! 😱\n\nHe knocked Chris Weidman out inside TWO MINUTES to move to a perfect 12-0!\n\nStatement. Made…'}
# {'tag': '#UFCBoston', 'date': '2019-10-19', 'tweet': 'RT @DamonMartin: Greg Hardy’s win overturned to no contest for illegal use of inhaler, team plans to appeal\n#UFC #UFCBoston https://t.co/Jw…'}
# {'tag': '#UFCBoston', 'date': '2019-10-19', 'tweet': 'RT @MikeBohnMMA: UFC has announced the fight between Greg Hardy and Ben Sosoli has been overturned to a no-contest due to the inhaler use.…'}
# {'tag': '#UFCBoston', 'date': '2019-10-19', 'tweet': 'RT @UFCEurope: No controversy this time round! ❌\n\n@PanteraUFC showed the true warrior spirit at #UFCBoston! 👏 https://t.co/tZfLxQD18U'}
# {'tag': '#UFCBoston', 'date': '2019-10-19', 'tweet': 'RT @VonPreux: Dominick "The Devastator" Reyes (12-0) hands Chris Weidman his fifth KO loss in six fights, countering the former middleweigh…'}
# {'tag': '#UFCBoston', 'date': '2019-10-19', 'tweet': 'RT @MMAFighting: And @panteraufc takes the unanimous decision (29x28 x3) against Jeremy Stephens #UFCBoston #bodykick\nhttps://t.co/X2IWV1us…'}
# {'tag': '#UFCBoston', 'date': '2019-10-19', 'tweet': "@UFC You've got to book Weidman vs Rockhold. Glass Chin vs Glass Chin. #UFCBoston"}
# {'tag': '#UFCBoston', 'date': '2019-10-19', 'tweet': 'RT @MMAFighting: Yair Rodriguez vs. Jeremy Stephens full fight video highlights #ufcboston https://t.co/gjh6F29Pgc https://t.co/Phq7VPdNDc'}
# {'tag': '#UFCBoston', 'date': '2019-10-19', 'tweet': 'RT @MMAFighting: @DamonMartin Some action from Rodriguez-Stephens #UFConESPN6 #UFCBoston https://t.co/hkWUhfUmS2'}
# {'tag': '#UFCBoston', 'date': '2019-10-19', 'tweet': 'Kinda sucks bc he said asked and they said yes lol'}
# {'tag': '#UFCBoston', 'date': '2019-10-19', 'tweet': 'RT @UFC_CA: What a fight!!\n\nWhere does it land on your FOTY list?? #UFCBoston https://t.co/jdQiskGfmm'}
# {'tag': '#UFCBoston', 'date': '2019-10-19', 'tweet': 'RT @MMAFighting: Wow, the power of @DomReyes in that KO of Weidman #UFCBoston -- he wants Jones next, what do you think?'}
# {'tag': '#UFCBoston', 'date': '2019-10-19', 'tweet': 'RT @Xdeep13: Mark Ratner said Greg Hardy using his inhaler in between rounds was completely illegal.  Should it be a DQ or no contest?  For…'}
# {'tag': '#UFCBoston', 'date': '2019-10-19', 'tweet': 'RT @MMAFighting: And winner by TKO at 1:43 of the first round, @DomReyes #UFCBoston https://t.co/wNKbCyBiH8'}
# {'tag': '#UFCBoston', 'date': '2019-10-19', 'tweet': 'RT @BryanHamper: Great fight but you gotta feel for Jeremy, tide was turning and that was supposed to be 5 rounds.. would’ve liked to see h…'}
# {'tag': '#UFCBoston', 'date': '2019-10-19', 'tweet': 'Weidmans chin is gone. He got put out by a hammer fist 😭'}
# {'tag': '#UFCBoston', 'date': '2019-10-19', 'tweet': 'RT @MMAFighting: Dominick Reyes vs. Chris Weidman full fight video highlights #ufcboston https://t.co/ixYkADJKmZ https://t.co/yxtfRl0Awf'}
# ---------------------------------------------------------------------------
# WantReadError                             Traceback (most recent call last)
# ~/anaconda3/lib/python3.7/site-packages/urllib3/contrib/pyopenssl.py in recv_into(self, *args, **kwargs)
#     296         try:
# --> 297             return self.connection.recv_into(*args, **kwargs)
#     298         except OpenSSL.SSL.SysCallError as e:
#
# ~/anaconda3/lib/python3.7/site-packages/OpenSSL/SSL.py in recv_into(self, buffer, nbytes, flags)
#    1821             result = _lib.SSL_read(self._ssl, buf, nbytes)
# -> 1822         self._raise_ssl_error(self._ssl, result)
#    1823
#
# ~/anaconda3/lib/python3.7/site-packages/OpenSSL/SSL.py in _raise_ssl_error(self, ssl, result)
#    1621         if error == _lib.SSL_ERROR_WANT_READ:
# -> 1622             raise WantReadError()
#    1623         elif error == _lib.SSL_ERROR_WANT_WRITE:
#
# WantReadError:
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-25-e73835062a77> in <module>
#      32         listeners.append(PipelineListener(top_n[i],time_limit=time_limit))
#      33         streams.append(tweepy.Stream(auth = api.auth, listener=listeners[i]))
# ---> 34         streams[i].filter(track=[top_n[i]], is_async=False, languages=["en"])
#      35         streams[i].disconnect()
#
# ~/anaconda3/lib/python3.7/site-packages/tweepy/streaming.py in filter(self, follow, track, is_async, locations, stall_warnings, languages, encoding, filter_level)
#     472             self.body['filter_level'] = filter_level.encode(encoding)
#     473         self.session.params = {'delimited': 'length'}
# --> 474         self._start(is_async)
#     475
#     476     def sitestream(self, follow, stall_warnings=False,
#
# ~/anaconda3/lib/python3.7/site-packages/tweepy/streaming.py in _start(self, is_async)
#     387             self._thread.start()
#     388         else:
# --> 389             self._run()
#     390
#     391     def on_closed(self, resp):
#
# ~/anaconda3/lib/python3.7/site-packages/tweepy/streaming.py in _run(self)
#     287                     self.snooze_time = self.snooze_time_step
#     288                     self.listener.on_connect()
# --> 289                     self._read_loop(resp)
#     290             except (Timeout, ssl.SSLError) as exc:
#     291                 # This is still necessary, as a SSLError can actually be
#
# ~/anaconda3/lib/python3.7/site-packages/tweepy/streaming.py in _read_loop(self, resp)
#     337             length = 0
#     338             while not resp.raw.closed:
# --> 339                 line = buf.read_line()
#     340                 stripped_line = line.strip() if line else line # line is sometimes None so we need to check here
#     341                 if not stripped_line:
#
# ~/anaconda3/lib/python3.7/site-packages/tweepy/streaming.py in read_line(self, sep)
#     198             else:
#     199                 start = len(self._buffer)
# --> 200             self._buffer += self._stream.read(self._chunk_size)
#     201         return six.b('')
#     202
#
# ~/anaconda3/lib/python3.7/site-packages/urllib3/response.py in read(self, amt, decode_content, cache_content)
#     440             else:
#     441                 cache_content = False
# --> 442                 data = self._fp.read(amt)
#     443                 if amt != 0 and not data:  # Platform-specific: Buggy versions of Python.
#     444                     # Close the connection when no data is returned
#
# ~/anaconda3/lib/python3.7/http/client.py in read(self, amt)
#     445             # Amount is given, implement using readinto
#     446             b = bytearray(amt)
# --> 447             n = self.readinto(b)
#     448             return memoryview(b)[:n].tobytes()
#     449         else:
#
# ~/anaconda3/lib/python3.7/http/client.py in readinto(self, b)
#     479
#     480         if self.chunked:
# --> 481             return self._readinto_chunked(b)
#     482
#     483         if self.length is not None:
#
# ~/anaconda3/lib/python3.7/http/client.py in _readinto_chunked(self, b)
#     574         try:
#     575             while True:
# --> 576                 chunk_left = self._get_chunk_left()
#     577                 if chunk_left is None:
#     578                     return total_bytes
#
# ~/anaconda3/lib/python3.7/http/client.py in _get_chunk_left(self)
#     542                 self._safe_read(2)  # toss the CRLF at the end of the chunk
#     543             try:
# --> 544                 chunk_left = self._read_next_chunk_size()
#     545             except ValueError:
#     546                 raise IncompleteRead(b'')
#
# ~/anaconda3/lib/python3.7/http/client.py in _read_next_chunk_size(self)
#     502     def _read_next_chunk_size(self):
#     503         # Read the next chunk size from the file
# --> 504         line = self.fp.readline(_MAXLINE + 1)
#     505         if len(line) > _MAXLINE:
#     506             raise LineTooLong("chunk size")
#
# ~/anaconda3/lib/python3.7/socket.py in readinto(self, b)
#     587         while True:
#     588             try:
# --> 589                 return self._sock.recv_into(b)
#     590             except timeout:
#     591                 self._timeout_occurred = True
#
# ~/anaconda3/lib/python3.7/site-packages/urllib3/contrib/pyopenssl.py in recv_into(self, *args, **kwargs)
#     307                 raise
#     308         except OpenSSL.SSL.WantReadError:
# --> 309             if not util.wait_for_read(self.socket, self.socket.gettimeout()):
#     310                 raise timeout('The read operation timed out')
#     311             else:
#
# ~/anaconda3/lib/python3.7/site-packages/urllib3/util/wait.py in wait_for_read(sock, timeout)
#     141     Returns True if the socket is readable, or False if the timeout expired.
#     142     """
# --> 143     return wait_for_socket(sock, read=True, timeout=timeout)
#     144
#     145
#
# ~/anaconda3/lib/python3.7/site-packages/urllib3/util/wait.py in poll_wait_for_socket(sock, read, write, timeout)
#     102         return poll_obj.poll(t)
#     103
# --> 104     return bool(_retry_on_intr(do_poll, timeout))
#     105
#     106
#
# ~/anaconda3/lib/python3.7/site-packages/urllib3/util/wait.py in _retry_on_intr(fn, timeout)
#      40     # Modern Python, that retries syscalls by default
#      41     def _retry_on_intr(fn, timeout):
# ---> 42         return fn(timeout)
#      43 else:
#      44     # Old and broken Pythons.
#
# ~/anaconda3/lib/python3.7/site-packages/urllib3/util/wait.py in do_poll(t)
#     100         if t is not None:
#     101             t *= 1000
# --> 102         return poll_obj.poll(t)
#     103
#     104     return bool(_retry_on_intr(do_poll, timeout))
#
# KeyboardInterrupt:
